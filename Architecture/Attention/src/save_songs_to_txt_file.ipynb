# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/cleaned-data-with-features.csv")

# %%
data.head(3)
# Out:
#    Unnamed: 0               song_name  \
# 0           0              Tim McGraw
# 1           1         Picture To Burn
# 2           2  Teardrops On My Guitar
#
#                                               lyrics  popularity release_data  \
# 0  He said the way my blue eyes shined\nPut those...          70   2006-10-24
# 1  State the obvious I didnt get my perfect fanta...          72   2006-10-24
# 2  Drew looks at me\nI fake a smile so he wont se...          69   2006-10-24
#
#    duration  explicit  danceability  energy  loudness  ...  liveness  valence  \
# 0    232106     False         0.580   0.491    -6.462  ...    0.1210    0.425
# 1    173066     False         0.658   0.877    -2.098  ...    0.0962    0.821
# 2    203040     False         0.621   0.417    -6.941  ...    0.1190    0.289
#
#      tempo  time_signature  stop_word_count  word_count  line_count  \
# 0   76.009               4              121         313          55
# ...

# %%
songs = data['song_name'].values
lyrics = data['lyrics'].values
combined = [f"Song Name: {song}\n{lyric}\n" for song, lyric in zip(songs, lyrics)]

all_songs = "\n-----\n".join(combined)
with open("../data/songs.txt", "w") as f:
    f.write(all_songs)
